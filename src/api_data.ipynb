# %% [markdown]
# Libraries

# %%
import pandas as pd
import numpy as np
import requests
import folium

import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
import pickle as pkl

from pathlib import Path

# %%
DATA_DIR = Path("..") / "data"

# %%
# Extracting data from Eurostat to choose the countries we are studying
eurostat_satisfaction_query = "https://ec.europa.eu/eurostat/api/dissemination/statistics/1.0/data/ilc_pw01?lang=en&isced11=TOTAL&indic_wb=LIFESAT&sex=T&age=Y_GE16&geo=EA20&geo=BE&geo=BG&geo=CZ&geo=DK&geo=DE&geo=EE&geo=IE&geo=EL&geo=ES&geo=FR&geo=HR&geo=IT&geo=CY&geo=LV&geo=LT&geo=LU&geo=HU&geo=MT&geo=NL&geo=AT&geo=PL&geo=PT&geo=RO&geo=SI&geo=SK&geo=FI&geo=SE&geo=IS&geo=NO&geo=CH&geo=UK&geo=ME&geo=MK&geo=AL&geo=RS&geo=TR&geo=XK&time=2022"
satisfaction_response = requests.get(eurostat_satisfaction_query)
satisfaction_json = satisfaction_response.json()

countries_id = satisfaction_json["dimension"]["geo"]["category"]["index"]
satisfaction_values = satisfaction_json["value"]
countries_full_name = satisfaction_json["dimension"]["geo"]["category"]["label"]

satisfaction_values_dict = {}
satisfaction_per_country_code = {}
final_satisf_dict = {}

for id in countries_id.values():
    satisfaction_values_dict[id] = satisfaction_values.get(str(id))

for i, j in zip(countries_id, satisfaction_values_dict):
    satisfaction_per_country_code[i] = satisfaction_values_dict[j]

for i, j in zip(countries_full_name.values(), satisfaction_per_country_code):
    final_satisf_dict.update({i: satisfaction_per_country_code[j]})


eurostat_gpd_query = "https://ec.europa.eu/eurostat/api/dissemination/statistics/1.0/data/tipsau10?lang=en&unit=CP_MNAC&geo=EA20&geo=BE&geo=BG&geo=CZ&geo=DK&geo=DE&geo=EE&geo=IE&geo=EL&geo=ES&geo=FR&geo=HR&geo=IT&geo=CY&geo=LV&geo=LT&geo=LU&geo=HU&geo=MT&geo=NL&geo=AT&geo=PL&geo=PT&geo=RO&geo=SI&geo=SK&geo=FI&geo=SE&time=2022"
gpd_response = requests.get(eurostat_gpd_query)
gpd_json = gpd_response.json()

gpd_values = gpd_json["value"]

gpd_values_dict = {}
gpd_per_country_code = {}
final_gpd_dict = {}

for id in countries_id.values():
    gpd_values_dict[id] = gpd_values.get(str(id))

for i, j in zip(countries_id, gpd_values_dict):
    gpd_per_country_code[i] = gpd_values_dict[j]

for i, j in zip(countries_full_name.values(), gpd_per_country_code):
    final_gpd_dict.update({i: gpd_per_country_code[j]})

# %%
# Creating a Dataframe with the info found
eurostat_data = pd.DataFrame(
    {
        "Country": final_satisf_dict.keys(),
        "Satisfaction": final_satisf_dict.values(),
        "GPD": final_gpd_dict.values(),
    }
)

eurostat_data = eurostat_data.drop(0)  # Aqui elemininamos los 23 paises
eurostat_data.loc[37, "Country"] = "Kosovo"

eurostat_data
# Out:
#             Country  Satisfaction         GPD
# 1           Belgium           7.6    554044.3
# 2          Bulgaria           5.6    167809.0
# 3           Czechia           7.4   6786742.0
# 4           Denmark           7.5   2831643.9
# 5           Germany           6.5   3876810.0
# 6           Estonia           7.2     36011.1
# 7           Ireland           7.4    506282.4
# 8            Greece           6.7    206620.4
# 9             Spain           7.1   1346377.0
# 10           France           7.0   2639092.0
# 11          Croatia           6.8     67993.1
# 12            Italy           7.2   1962845.8
# 13           Cyprus           7.2     27777.0
# 14           Latvia           6.8     38386.2
# 15        Lithuania           7.1     67399.1
# 16       Luxembourg           7.2     77529.0
# 17          Hungary           6.9  66075190.0
# 18            Malta           7.4     17432.3
# 19      Netherlands           7.6    958549.0
# 20          Austria           7.9    447217.6
# 21           Poland           7.7   3067495.0
# 22         Portugal           7.0    242340.8
# 23          Romania           7.7   1401345.4
# 24         Slovenia           7.5     57037.7
# 25         Slovakia           7.0    109645.2
# 26          Finland           7.7    267687.0
# 27           Sweden           7.4   5971551.0
# 28          Iceland           NaN         NaN
# 29           Norway           7.6         NaN
# 30      Switzerland           8.0         NaN
# 31   United Kingdom           NaN         NaN
# 32       Montenegro           5.8         NaN
# 33  North Macedonia           NaN         NaN
# 34          Albania           NaN         NaN
# 35           Serbia           6.1         NaN
# 36          Türkiye           NaN         NaN
# 37           Kosovo           NaN         NaN

# %%
# Transforming info to make it easy to work with
# Converting all coins to Euro to be able to study them
frankfurter_url = "https://api.frankfurter.app"
ffdate = "2022-12-21"
non_euro_coins = ["RON", "HUF", "CHF", "CZK", "SEK", "PLN", "DKK", "BGN"]
conversors = {}

hrk = (
    7,
    53450,
)  # since 2023 Croatia has been using the euro, so we take the last exchange rate from 2022

hrk = float(hrk[0])

for coin in non_euro_coins:
    endpoint = f"{frankfurter_url}/{ffdate}?to={coin}"
    conversor_dict = requests.get(endpoint).json()
    conversor = conversor_dict["rates"][coin]
    conversors[coin] = conversor

conversors["HRK"] = hrk

non_euro_countries_coins = {
    "RON": "Romania",
    "HUF": "Hungary",
    "CHF": "Switzerland",
    "CZK": "Czechia",
    "SEK": "Sweden",
    "PLN": "Poland",
    "DKK": "Denmark",
    "BGN": "Bulgaria",
    "HRK": "Croatia",
}


# Filter the rows of the eurostat_data dataframe where Country is equal to non_euro_countries_coins

filtered_df = eurostat_data[
    eurostat_data["Country"].isin(non_euro_countries_coins.values())
]


# Iterating over the filtered rows and dividing the GPD value by the corresponding conversion in the conversors dictionary

# iterrows() returns the index and the row as a Series
for index, row in filtered_df.iterrows():

    country = row["Country"]

    """
    The following line of code is making a list of the keys of the non_euro_countries_coins dictionary to be able
    to make indexing. Then we are making a list from the values of the dictionary and we are getting the index of the
    country we are iterating.
    """
    coin = list(non_euro_countries_coins.keys())[
        list(non_euro_countries_coins.values()).index(country)
    ]

    gpd_value = row["GPD"]
    conversion_rate = conversors[coin]
    converted_gpd = gpd_value / conversion_rate
    eurostat_data.loc[index, "GPD"] = round(converted_gpd, 3)

# %%
# Creating stardarized data to make a ponderation
eurostat_data["GPD"] = round(
    eurostat_data["GPD"].fillna(eurostat_data["GPD"].mean()), 3
)
eurostat_data["Satisfaction"] = eurostat_data["Satisfaction"].fillna(
    eurostat_data["Satisfaction"].mean()
)
eurostat_data["Standarized Satisfaction"] = round(
    (eurostat_data["Satisfaction"] - eurostat_data["Satisfaction"].mean())
    / eurostat_data["Satisfaction"].std(),
    3,
)
eurostat_data["Standarized GPD"] = round(
    (eurostat_data["GPD"] - eurostat_data["GPD"].mean()) / eurostat_data["GPD"].std(), 3
)
eurostat_data["Ponderation"] = (
    eurostat_data["Standarized Satisfaction"] * 0.6
    + eurostat_data["Standarized GPD"] * 0.4
)

# %%
eurostat_data
# Out:
#             Country  Satisfaction        GPD  Standarized Satisfaction  \
# 1           Belgium      7.600000   554044.0                     0.873
# 2          Bulgaria      5.600000    11469.0                    -2.993
# 3           Czechia      7.400000       20.0                     0.486
# 4           Denmark      7.500000      925.0                     0.680
# 5           Germany      6.500000  3876810.0                    -1.253
# 6           Estonia      7.200000    36011.0                     0.100
# 7           Ireland      7.400000   506282.0                     0.486
# 8            Greece      6.700000   206620.0                    -0.867
# 9             Spain      7.100000  1346377.0                    -0.094
# 10           France      7.000000  2639092.0                    -0.287
# 11          Croatia      6.800000       28.0                    -0.673
# 12            Italy      7.200000  1962846.0                     0.100
# 13           Cyprus      7.200000    27777.0                     0.100
# 14           Latvia      6.800000    38386.0                    -0.673
# 15        Lithuania      7.100000    67399.0                    -0.094
# 16       Luxembourg      7.200000    77529.0                     0.100
# 17          Hungary      6.900000        0.0                    -0.480
# 18            Malta      7.400000    17432.0                     0.486
# 19      Netherlands      7.600000   958549.0                     0.873
# 20          Austria      7.900000   447218.0                     1.453
# 21           Poland      7.700000     6469.0                     1.066
# 22         Portugal      7.000000   242341.0                    -0.287
# 23          Romania      7.700000     2443.0                     1.066
# 24         Slovenia      7.500000    57038.0                     0.680
# 25         Slovakia      7.000000   109645.0                    -0.287
# 26          Finland      7.700000   267687.0                     1.066
# 27           Sweden      7.400000      399.0                     0.486
# 28          Iceland      7.148387   500579.0                     0.000
# 29           Norway      7.600000   500579.0                     0.873
# 30      Switzerland      8.000000   508925.0                     1.646
# 31   United Kingdom      7.148387   500579.0                     0.000
# 32       Montenegro      5.800000   500579.0                    -2.606
# 33  North Macedonia      7.148387   500579.0                     0.000
# 34          Albania      7.148387   500579.0                     0.000
# 35           Serbia      6.100000   500579.0                    -2.026
# 36          Türkiye      7.148387   500579.0                     0.000
# 37           Kosovo      7.148387   500579.0                     0.000
#
#     Standarized GPD  Ponderation
# 1             0.069       0.5514
# 2            -0.613      -2.0410
# 3            -0.627       0.0408
# 4            -0.626       0.1576
# 5             4.241       0.9446
# 6            -0.582      -0.1728
# 7             0.009       0.2952
# 8            -0.368      -0.6674
# 9             1.064       0.3692
# 10            2.687       0.9026
# 11           -0.627      -0.6546
# 12            1.838       0.7952
# 13           -0.592      -0.1768
# 14           -0.579      -0.6354
# 15           -0.542      -0.2732
# 16           -0.530      -0.1520
# 17           -0.627      -0.5388
# 18           -0.605       0.0496
# 19            0.577       0.7546
# 20           -0.065       0.8458
# 21           -0.619       0.3920
# 22           -0.323      -0.3014
# 23           -0.624       0.3900
# 24           -0.555       0.1860
# 25           -0.489      -0.3678
# 26           -0.291       0.5232
# 27           -0.626       0.0412
# 28            0.002       0.0008
# 29            0.002       0.5246
# 30            0.012       0.9924
# 31            0.002       0.0008
# 32            0.002      -1.5628
# 33            0.002       0.0008
# 34            0.002       0.0008
# 35            0.002      -1.2148
# 36            0.002       0.0008
# 37            0.002       0.0008

# %%
# Upload of ponderations to Airtable
airtable_base_url = "https://api.airtable.com/v0"
atTOKEN = (
    "patXW3EcWQjnbHnOb.d33113d79b3f425be1e4712fdf16cb0291bb974b6ce1d5653435db3faddb9ffb"
)
BASE_ID = "appZYI77p6tdWcbXo"
TABLE_ID1 = "tblfPPHv9mkLBVYK2"

headers = {"Authorization": f"Bearer {atTOKEN}", "Content-Type": "application/json"}

eurostat_table_endpoint = f"{airtable_base_url}/{BASE_ID}/{TABLE_ID1}"

for i in range(0, eurostat_data.shape[0], 10):
    try:

        datos_subir = {
            "records": [
                {"fields": eurostat_data.iloc[j, :].to_dict()} for j in range(i, i + 10)
            ],
            "typecast": True,
        }

    except:

        datos_subir = {
            "records": [
                {"fields": eurostat_data.iloc[j, :].to_dict()}
                for j in range(i, eurostat_data.shape[0])
            ],
            "typecast": True,
        }
    response = requests.post(
        url=eurostat_table_endpoint, json=datos_subir, headers=headers
    )

# %%
# Choosing our countries to study
eurostat_data.sort_values("Ponderation", ascending=False).head(3).reset_index().drop(
    "index", axis=1
)
# Out:
#        Country  Satisfaction        GPD  Standarized Satisfaction  \
# 0  Switzerland           8.0   508925.0                     1.646
# 1      Germany           6.5  3876810.0                    -1.253
# 2       France           7.0  2639092.0                    -0.287
#
#    Standarized GPD  Ponderation
# 0            0.012       0.9924
# 1            4.241       0.9446
# 2            2.687       0.9026

# %%
# Countries to study
final_cities = {
    "bern": {"lat": 46.94809, "lon": 7.44744},
    "berlin": {"lat": 52.52437, "lon": 13.41053},
    "paris": {"lat": 48.85341, "lon": 2.3488},
}

cities = list(final_cities.keys())

# %%
with open(DATA_DIR / "cities.pkl", "bw") as f:
    pkl.dump(cities, f)

# %%
# Data extraction of current weather in each country
API_KEY_opw = "b4af990166923720f3f2ca0daa2ee53e"
search_url_opw = "https://api.openweathermap.org/data/2.5/weather"

weathers = []

for fcountry in final_cities.items():
    endpoint = f'{search_url_opw}?lat={fcountry[1]["lat"]}&lon={fcountry[1]["lon"]}&appid={API_KEY_opw}&units=metric'
    response = requests.get(url=endpoint)
    weather = response.json()
    weathers.append(weather)

# %%
# Creating a DataFrame with the info of weathers extracted
countries_id = []
cities = []
mains = []
temperatures = []
temps_min = []
temps_max = []
pressures = []
humidities = []
wind_speeds = []

for weather in weathers:

    country = weather["sys"].get("country")
    city = weather.get("name")
    main = weather["weather"][0].get("main")
    temperature = weather["main"].get("temp")
    temp_min = weather["main"].get("temp_min")
    temp_max = weather["main"].get("temp_max")
    pressure = weather["main"].get("pressure")
    humidity = weather["main"].get("humidity")
    wind_speed = weather["wind"].get("speed")

    countries_id.append(country)
    cities.append(city)
    mains.append(main)
    temperatures.append(temperature)
    temps_min.append(temp_min)
    temps_max.append(temp_max)
    pressures.append(pressure)
    humidities.append(humidity)
    wind_speeds.append(wind_speed)

weather_data = pd.DataFrame(
    {
        "Country": countries_id,
        "City": cities,
        "Main": mains,
        "Temperature (ºC)": temperatures,
        "Minimun temperature (ºC)": temps_min,
        "Maximun temperature (ºC)": temps_max,
        "Pressure (hPa)": pressures,
        "Humidity (%)": humidities,
        "Wind speed (meter/sec)": wind_speeds,
    }
)

weather_data
# Out:
#   Country    City    Main  Temperature (ºC)  Minimun temperature (ºC)  \
# 0      CH    Bern   Clear             14.44                     11.42
# 1      DE  Berlin  Clouds             10.73                     10.00
# 2      FR   Paris   Clear             18.28                     16.88
#
#    Maximun temperature (ºC)  Pressure (hPa)  Humidity (%)  \
# 0                     15.50            1024            55
# 1                     11.66            1021            83
# 2                     19.28            1025            56
#
#    Wind speed (meter/sec)
# 0                    3.60
# 1                    5.66
# 2                    3.09

# %%
# Upload of current weather data to Airtable
TABLE_ID2 = "tblaqVEaHP4edqx7T"

headers = {"Authorization": f"Bearer {atTOKEN}", "Content-Type": "application/json"}

weather_table_endpoint = f"{airtable_base_url}/{BASE_ID}/{TABLE_ID2}"

for i in range(0, weather_data.shape[0], 10):
    try:

        datos_subir = {
            "records": [
                {"fields": weather_data.iloc[j, :].to_dict()} for j in range(i, i + 10)
            ],
            "typecast": True,
        }

    except:

        datos_subir = {
            "records": [
                {"fields": weather_data.iloc[j, :].to_dict()}
                for j in range(i, weather_data.shape[0])
            ],
            "typecast": True,
        }
    response = requests.post(
        url=weather_table_endpoint, json=datos_subir, headers=headers
    )

# %%
# Data extraction of interesting places (museums, colleges, churchs)
categories_data = pd.read_csv(DATA_DIR / "categories id.csv")

categorie_Ids = categories_data[
    categories_data["Category Label"].isin(
        ["Museums", "Colleges and Universities", "Spiritual Centers"]
    )
]["Category ID"].to_list()

CLIENT_ID_fsq = "MMU5IDIAX0XGQO5W15DRXXHZSBWH0TRIYV3WT342FAC1EQBI"
CLIENT_SECRET_fsq = "3XN11U5ERZ0ZFFHXZPQLO0LKIPFRWFXAWEJFHKZZO12LAFJN"
API_KEY_fsq = "fsq3OpNt1w78JygPc1Dt+Om4ekR/16kTn94lfiYSWW3Ci74="
search_url_fsq = "https://api.foursquare.com/v3/places/search"

# %%
fsq_ids = []
countries = []
localities = []
categories = []
names = []
locations = []
latitudes = []
longitudes = []
institutions = ["museum", "College and University", "Spiritual Center"]

for fcountry in final_cities.items():

    for institution in institutions:

        url_params = {
            "query": institution,
            "ll": f"{fcountry[1]['lat']},{fcountry[1]['lon']}",
            "open_now": None,
            "limit": 50,
            "radius": 10_000,
            "category": ",".join(categorie_Ids),
        }

        headers = {"accept": "application/json", "Authorization": API_KEY_fsq}
        response = requests.get(url=search_url_fsq, headers=headers, params=url_params)
        foursquare_json = response.json()

        for value in range(len(foursquare_json["results"])):

            fsq_id = foursquare_json["results"][value].get("fsq_id")
            country = foursquare_json["results"][value]["location"].get("country")
            locality = foursquare_json["results"][value]["location"].get("locality")
            category = foursquare_json["results"][value]["categories"][0].get("name")
            name = foursquare_json["results"][value].get("name")
            location = foursquare_json["results"][value]["location"].get(
                "formatted_address"
            )
            latitude = foursquare_json["results"][value]["geocodes"]["main"].get(
                "latitude"
            )
            longitude = foursquare_json["results"][value]["geocodes"]["main"].get(
                "longitude"
            )

            fsq_ids.append(fsq_id)
            countries.append(country)
            localities.append(locality)
            categories.append(category)
            names.append(name)
            locations.append(location)
            latitudes.append(latitude)
            longitudes.append(longitude)

foursquare_data = pd.DataFrame(
    {
        "Fsq_Id": fsq_ids,
        "Country": countries,
        "Locality": localities,
        "Category": categories,
        "Name": names,
        "Location": locations,
        "Latitude": latitudes,
        "Longitude": longitudes,
    }
)

# %%
# Dataframe with the data about interesting places extracted
foursquare_data
# Out:
#                        Fsq_Id Country           Locality  \
# 0    4be277911dd22d7f7f3094bd      CH               Bern
# 1    4b4c5125f964a520dfb026e3      CH               Bern
# 2    4fd49753e4b03121ce7823b6      CH               Bern
# 3    4ba3c1e5f964a520fe5b38e3      CH               Bern
# 4    4ca58ce1965c9c744881c7fa      CH               Bern
# ..                        ...     ...                ...
# 445  4bea8d9ba9900f4772981640      FR              Paris
# 446  4cc2e10cb2beb1f7459d124c      FR  Neuilly-sur-Seine
# 447  4adcda09f964a520f83321e3      FR        Saint-Denis
# 448  dbbc68275e11478976a4ed8e      FR              Paris
# 449  fe475fe862b64b923124643a      FR             Vanves
#
#                      Category  \
# 0                      Museum
# 1                  Art Museum
# 2              Science Museum
# 3                      Museum
# 4                      Museum
# ..                        ...
# 445  Community and Government
# 446                    Church
# 447                 Structure
# 448          Spiritual Center
# 449          Spiritual Center
#
#                                                 Name  \
# 0     Bernisches Historisches Museum Einstein Museum
# 1                                   Kunstmuseum Bern
# 2                                     Einsteinmuseum
# 3                           Museum für Kommunikation
# 4                           Naturhistorisches Museum
# ..                                               ...
# 445                        Sanctuaire Sainte-Thérèse
# 446                              Église Saint Pierre
# 447  Basilica of Saint Denis (Basilique Saint-Denis)
# 448                            Paroisses Catholiques
# 449                              Paroisses de Vanves
#
#                                               Location   Latitude  Longitude
# 0                           Helvetiaplatz 5, 3005 Bern  46.942953   7.449349
# 1                           Hodlerstr. 8-12, 3011 Bern  46.951048   7.443254
# 2                           Helvetiaplatz 5, 3005 Bern  46.943129   7.449336
# 3                        Helvetiastrasse 16, 3005 Bern  46.941801   7.450036
# 4                           Bernastrasse 15, 3005 Bern  46.942141   7.448943
# ..                                                 ...        ...        ...
# 445  40 rue Jean de la Fontaine (Apprentis d'Auteui...  48.851557   2.271186
# 446     boulevard Jean Mermoz, 92200 Neuilly-sur-Seine  48.884183   2.271652
# 447    1 rue de la Légion d'Honneur, 93200 Saint-Denis  48.935497   2.359765
# 448            2 avenue Stéphane Mallarmé, 75017 Paris  48.886862   2.293162
# 449            17 place de la République, 92170 Vanves  48.821032   2.286097
#
# [450 rows x 8 columns]

# %%
# Upload of interesting places to Airtable
TABLE_ID3 = "tblDuWR3nXGmk9OHl"

headers = {"Authorization": f"Bearer {atTOKEN}", "Content-Type": "application/json"}

foursquare_table_endpoint = f"{airtable_base_url}/{BASE_ID}/{TABLE_ID3}"

for i in range(0, foursquare_data.shape[0], 10):
    try:

        datos_subir = {
            "records": [
                {"fields": foursquare_data.iloc[j, :].to_dict()}
                for j in range(i, i + 10)
            ],
            "typecast": True,
        }

    except:

        datos_subir = {
            "records": [
                {"fields": foursquare_data.iloc[j, :].to_dict()}
                for j in range(i, foursquare_data.shape[0])
            ],
            "typecast": True,
        }
    response = requests.post(
        url=foursquare_table_endpoint, json=datos_subir, headers=headers
    )

# %% [markdown]
# Now we proceed to analyze the data obtained

# %%
# Visualization of the ponderations
px.scatter(
    data_frame=eurostat_data,
    x="Country",
    y="Ponderation",
    color="Standarized Satisfaction",
)

# %%
# Visualization of current weather data
px.bar(
    data_frame=weather_data,
    x="City",
    y="Temperature (ºC)",
    hover_data=[
        "Main",
        "Minimun temperature (ºC)",
        "Maximun temperature (ºC)",
        "Pressure (hPa)",
        "Humidity (%)",
        "Wind speed (meter/sec)",
    ],
    color="Humidity (%)",
)

# %%
# Visualization of Valencia map with the interesting places
sf_map_bern = folium.Map(
    location=[final_cities["bern"]["lat"], final_cities["bern"]["lon"]],
    zoom_start=14,
)

interest_places_bern = folium.map.FeatureGroup()

for lat, lon, name in zip(
    foursquare_data[foursquare_data["Country"] == "CH"]["Latitude"],
    foursquare_data[foursquare_data["Country"] == "CH"]["Longitude"],
    foursquare_data["Name"],
):

    interest_places_bern.add_child(folium.Marker(location=[lat, lon], popup=name))

sf_map_bern.add_child(interest_places_bern)

sf_map_bern
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2586804c0d1637ced0f8465b51955074 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2586804c0d1637ced0f8465b51955074&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2586804c0d1637ced0f8465b51955074 = L.map(
#                 &quot;map_2586804c0d1637ced0f8465b51955074&quot;,
#                 {
#                     center: [46.94809, 7.44744],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c498782aae974a15fb70db553c287369 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c498782aae974a15fb70db553c287369.addTo(map_2586804c0d1637ced0f8465b51955074);
#
#
#             var feature_group_af27d4f39f7bbf08b63aedfe27ba31bb = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_65f681481e54e5ee5f6070003a96fabb = L.marker(
#                 [46.942953, 7.449349],
#                 {}
#             ).addTo(feature_group_af27d4f39f7bbf08b63aedfe27ba31bb);
#
#
#         var popup_ab4af6ab775266c01d011ea5776c5de5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4a8c670c68b62c65114e00b23475f0c9 = $(`&lt;div id=&quot;html_4a8c670c68b62c65114e00b23475f0c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bernisches Historisches Museum Einstein Museum&lt;/div&gt;`)[0];
#                 popup_ab4af6ab775266c01d011ea5776c5de5.setContent(html_4a8c670c68b62c65114e00b23475f0c9);
#
#
#
#         marker_65f681481e54e5ee5f6070003a96fabb.bindPopup(popup_ab4af6ab775266c01d011ea5776c5de5)
#         ;
#
#
#
#
#             var marker_8b4aca752ef4b84c6368a92915f6c20b = L.marker(
#                 [46.951048, 7.443254],
#                 {}
#             ).addTo(feature_group_af27d4f39f7bbf08b63aedfe27ba31bb);
#
#
#         var popup_576dea9e0317c61e4128d96371e0c729 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1e8c8aa84107372c1867deb685c12a37 = $(`&lt;div id=&quot;html_1e8c8aa84107372c1867deb685c12a37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kunstmuseum Bern&lt;/div&gt;`)[0];
#                 popup_576dea9e0317c61e4128d96371e0c729.setContent(html_1e8c8aa84107372c1867deb685c12a37);
#
#
#
#         marker_8b4aca752ef4b84c6368a92915f6c20b.bindPopup(popup_576dea9e0317c61e4128d96371e0c729)
#         ;
#
#
#
#
#             var marker_5d760655776cba20646fd61ff7f86d31 = L.marker(
#                 [46.943129, 7.449336],
#                 {}
#             ).addTo(feature_group_af27d4f39f7bbf08b63aedfe27ba31bb);
#
#
#         var popup_7a973ee76ef9b5a55d719b3c809a3042 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c5fff36467c7d82a588c8c6c6775cb2d = $(`&lt;div id=&quot;html_c5fff36467c7d82a588c8c6c6775cb2d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Einsteinmuseum&lt;/div&gt;`)[0];
#                 popup_7a973ee76ef9b5a55d719b3c809a3042.setContent(html_c5fff36467c7d82a588c8c6c6775cb2d);
#
#
#
#         marker_5d760655776cba20646fd61ff7f86d31.bindPopup(popup_7a973ee76ef9b5a55d719b3c809a3042)
#         ;
#
#
#
#
#             var marker_b09c6f6e9c9df04bb554fd326fe05cf9 = L.marker(
#                 [46.941801, 7.450036],
#                 {}
#             ).addTo(feature_group_af27d4f39f7bbf08b63aedfe27ba31bb);
#
#
#         var popup_19226b63bf010698f57f6295aa015e33 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8482784e05804257157183cb8dcfd3c8 = $(`&lt;div id=&quot;html_8482784e05804257157183cb8dcfd3c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Museum für Kommunikation&lt;/div&gt;`)[0];
#                 popup_19226b63bf010698f57f6295aa015e33.setContent(html_8482784e05804257157183cb8dcfd3c8);
#
#
#
#         marker_b09c6f6e9c9df04bb554fd326fe05cf9.bindPopup(popup_19226b63bf010698f57f6295aa015e33)
#         ;
#
#
#
#
#             var marker_3cd9387ca55ec7b31b5d99c37830aa95 = L.marker(
#                 [46.942141, 7.448943],
#                 {}
#             ).addTo(feature_group_af27d4f39f7bbf08b63aedfe27ba31bb);
#
#
#         var popup_f966e7e6a09ee643ea8544893fe4d130 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1952ae7c8f593d0e4c9ed29d9f1dc14b = $(`&lt;div id=&quot;html_1952ae7c8f593d0e4c9ed29d9f1dc14b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Naturhistorisches Museum&lt;/div&gt;`)[0];
#                 popup_f966e7e6a09ee643ea8544893fe4d130.setContent(html_1952ae7c8f593d0e4c9ed29d9f1dc14b);
#
#
#
#         marker_3cd9387ca55ec7b31b5d99c37830aa95.bindPopup(popup_f966e7e6a09ee643ea8544893f

# %%
# Visualization of London map with the interesting places
sf_map_berlin = folium.Map(
    location=[final_cities["berlin"]["lat"], final_cities["berlin"]["lon"]],
    zoom_start=12,
)

interest_places_berlin = folium.map.FeatureGroup()

for lat, lon, name in zip(
    foursquare_data[foursquare_data["Country"] == "DE"]["Latitude"],
    foursquare_data[foursquare_data["Country"] == "DE"]["Longitude"],
    foursquare_data["Name"],
):

    interest_places_berlin.add_child(folium.Marker(location=[lat, lon], popup=name))

sf_map_berlin.add_child(interest_places_berlin)

sf_map_berlin
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6facb8942c832e026b9c753315a421b3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6facb8942c832e026b9c753315a421b3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6facb8942c832e026b9c753315a421b3 = L.map(
#                 &quot;map_6facb8942c832e026b9c753315a421b3&quot;,
#                 {
#                     center: [52.52437, 13.41053],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_63ba0a7f999fb2c3c9705755f3311618 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_63ba0a7f999fb2c3c9705755f3311618.addTo(map_6facb8942c832e026b9c753315a421b3);
#
#
#             var feature_group_720c67ae98b085ec09fe74144bbde5e0 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_9041b1cf19252bff3f5d0c71e52cfc9a = L.marker(
#                 [52.520817, 13.409023],
#                 {}
#             ).addTo(feature_group_720c67ae98b085ec09fe74144bbde5e0);
#
#
#         var popup_52c5f6ff9a6c53115883f5b407b9a1a2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_886c944e251a684576069fb85b33a66a = $(`&lt;div id=&quot;html_886c944e251a684576069fb85b33a66a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bernisches Historisches Museum Einstein Museum&lt;/div&gt;`)[0];
#                 popup_52c5f6ff9a6c53115883f5b407b9a1a2.setContent(html_886c944e251a684576069fb85b33a66a);
#
#
#
#         marker_9041b1cf19252bff3f5d0c71e52cfc9a.bindPopup(popup_52c5f6ff9a6c53115883f5b407b9a1a2)
#         ;
#
#
#
#
#             var marker_38914c3b338fb78adeb8984d1fd8be63 = L.marker(
#                 [52.520878, 13.398214],
#                 {}
#             ).addTo(feature_group_720c67ae98b085ec09fe74144bbde5e0);
#
#
#         var popup_ea561f560b21806f637d86cbeb132ebe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_86a3e9aa74c372d8bf3296939385bf91 = $(`&lt;div id=&quot;html_86a3e9aa74c372d8bf3296939385bf91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kunstmuseum Bern&lt;/div&gt;`)[0];
#                 popup_ea561f560b21806f637d86cbeb132ebe.setContent(html_86a3e9aa74c372d8bf3296939385bf91);
#
#
#
#         marker_38914c3b338fb78adeb8984d1fd8be63.bindPopup(popup_ea561f560b21806f637d86cbeb132ebe)
#         ;
#
#
#
#
#             var marker_a3305be91701164f6bbb4767818b7597 = L.marker(
#                 [52.519451, 13.398742],
#                 {}
#             ).addTo(feature_group_720c67ae98b085ec09fe74144bbde5e0);
#
#
#         var popup_55eef20d25d280f3578049f3c4f82fe1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_de2a2573b6d7f25b9b90e09141d9722a = $(`&lt;div id=&quot;html_de2a2573b6d7f25b9b90e09141d9722a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Einsteinmuseum&lt;/div&gt;`)[0];
#                 popup_55eef20d25d280f3578049f3c4f82fe1.setContent(html_de2a2573b6d7f25b9b90e09141d9722a);
#
#
#
#         marker_a3305be91701164f6bbb4767818b7597.bindPopup(popup_55eef20d25d280f3578049f3c4f82fe1)
#         ;
#
#
#
#
#             var marker_1982eaa688ae05549eb064c554b1c62a = L.marker(
#                 [52.520091, 13.397937],
#                 {}
#             ).addTo(feature_group_720c67ae98b085ec09fe74144bbde5e0);
#
#
#         var popup_aabb4f6bc0ff7b0d3737d52a0654d6c7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_60ef5b073e914fae281b9a9e1ea40a93 = $(`&lt;div id=&quot;html_60ef5b073e914fae281b9a9e1ea40a93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Museum für Kommunikation&lt;/div&gt;`)[0];
#                 popup_aabb4f6bc0ff7b0d3737d52a0654d6c7.setContent(html_60ef5b073e914fae281b9a9e1ea40a93);
#
#
#
#         marker_1982eaa688ae05549eb064c554b1c62a.bindPopup(popup_aabb4f6bc0ff7b0d3737d52a0654d6c7)
#         ;
#
#
#
#
#             var marker_20a09dcbeccc43fa6a0c52dd5542f707 = L.marker(
#                 [52.516951, 13.405846],
#                 {}
#             ).addTo(feature_group_720c67ae98b085ec09fe74144bbde5e0);
#
#
#         var popup_e24a275bc76019d137e06bbe49ac47d1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2698bf5baee68e5d595d6dbf99b538c1 = $(`&lt;div id=&quot;html_2698bf5baee68e5d595d6dbf99b538c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Naturhistorisches Museum&lt;/div&gt;`)[0];
#                 popup_e24a275bc76019d137e06bbe49ac47d1.setContent(html_2698bf5baee68e5d595d6dbf99b538c1);
#
#
#
#         marker_20a09dcbeccc43fa6a0c52dd5542f707.bindPopup(popup_e24a275bc76019d137e0

# %%
# Visualization of Amsterdam map with the interesting places
sf_map_paris = folium.Map(
    location=[final_cities["paris"]["lat"], final_cities["paris"]["lon"]],
    zoom_start=14,
)

interest_places_paris = folium.map.FeatureGroup()

for lat, lon, name in zip(
    foursquare_data[foursquare_data["Country"] == "FR"]["Latitude"],
    foursquare_data[foursquare_data["Country"] == "FR"]["Longitude"],
    foursquare_data["Name"],
):

    interest_places_paris.add_child(folium.Marker(location=[lat, lon], popup=name))

sf_map_paris.add_child(interest_places_paris)

sf_map_paris
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_737fbd185a9248e1a2d63115686c3d8e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_737fbd185a9248e1a2d63115686c3d8e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_737fbd185a9248e1a2d63115686c3d8e = L.map(
#                 &quot;map_737fbd185a9248e1a2d63115686c3d8e&quot;,
#                 {
#                     center: [48.85341, 2.3488],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5a8576bfe4d3c969fa150f256b2bed91 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5a8576bfe4d3c969fa150f256b2bed91.addTo(map_737fbd185a9248e1a2d63115686c3d8e);
#
#
#             var feature_group_0efa5dbcf67e5f1fa8c71fecf912b190 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_34da8b63e2dec5b762f19dc751721e1f = L.marker(
#                 [48.855139, 2.358954],
#                 {}
#             ).addTo(feature_group_0efa5dbcf67e5f1fa8c71fecf912b190);
#
#
#         var popup_49ece94d8e40b7de3ae7f4dd45355ac7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e4a784a59c56d73a71cfcf2fc98fbec7 = $(`&lt;div id=&quot;html_e4a784a59c56d73a71cfcf2fc98fbec7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bernisches Historisches Museum Einstein Museum&lt;/div&gt;`)[0];
#                 popup_49ece94d8e40b7de3ae7f4dd45355ac7.setContent(html_e4a784a59c56d73a71cfcf2fc98fbec7);
#
#
#
#         marker_34da8b63e2dec5b762f19dc751721e1f.bindPopup(popup_49ece94d8e40b7de3ae7f4dd45355ac7)
#         ;
#
#
#
#
#             var marker_4ae1c9c98f5e823b6816f29c91e446f8 = L.marker(
#                 [48.850597, 2.343759],
#                 {}
#             ).addTo(feature_group_0efa5dbcf67e5f1fa8c71fecf912b190);
#
#
#         var popup_d8b9ed1a5a6bf2d9dae5623027ac291b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_11aeab6ffa127514606aa2b9d524c671 = $(`&lt;div id=&quot;html_11aeab6ffa127514606aa2b9d524c671&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kunstmuseum Bern&lt;/div&gt;`)[0];
#                 popup_d8b9ed1a5a6bf2d9dae5623027ac291b.setContent(html_11aeab6ffa127514606aa2b9d524c671);
#
#
#
#         marker_4ae1c9c98f5e823b6816f29c91e446f8.bindPopup(popup_d8b9ed1a5a6bf2d9dae5623027ac291b)
#         ;
#
#
#
#
#             var marker_8de40054f99a5c5dfdc030ea8ed1ec6b = L.marker(
#                 [48.86067750938799, 2.3524367809295654],
#                 {}
#             ).addTo(feature_group_0efa5dbcf67e5f1fa8c71fecf912b190);
#
#
#         var popup_64a544066424307f122dd2596f1a5a96 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a91ff6969334de6de34df81bede8bc70 = $(`&lt;div id=&quot;html_a91ff6969334de6de34df81bede8bc70&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Einsteinmuseum&lt;/div&gt;`)[0];
#                 popup_64a544066424307f122dd2596f1a5a96.setContent(html_a91ff6969334de6de34df81bede8bc70);
#
#
#
#         marker_8de40054f99a5c5dfdc030ea8ed1ec6b.bindPopup(popup_64a544066424307f122dd2596f1a5a96)
#         ;
#
#
#
#
#             var marker_6a5d9ada71d88e654faa90ac7c561e46 = L.marker(
#                 [48.856737, 2.339192],
#                 {}
#             ).addTo(feature_group_0efa5dbcf67e5f1fa8c71fecf912b190);
#
#
#         var popup_a610ac9a6c089a621aedab43b3f93ac3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c51018c8545b1ae70a90e8b66638af00 = $(`&lt;div id=&quot;html_c51018c8545b1ae70a90e8b66638af00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Museum für Kommunikation&lt;/div&gt;`)[0];
#                 popup_a610ac9a6c089a621aedab43b3f93ac3.setContent(html_c51018c8545b1ae70a90e8b66638af00);
#
#
#
#         marker_6a5d9ada71d88e654faa90ac7c561e46.bindPopup(popup_a610ac9a6c089a621aedab43b3f93ac3)
#         ;
#
#
#
#
#             var marker_5132c7eb468210326d0725a478c86cb7 = L.marker(
#                 [48.849113, 2.356847],
#                 {}
#             ).addTo(feature_group_0efa5dbcf67e5f1fa8c71fecf912b190);
#
#
#         var popup_130eb3b45d2c6b3fee1e39759bacb375 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d5ee73495e1b4e61e7e084aeed086c5c = $(`&lt;div id=&quot;html_d5ee73495e1b4e61e7e084aeed086c5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Naturhistorisches Museum&lt;/div&gt;`)[0];
#                 popup_130eb3b45d2c6b3fee1e39759bacb375.setContent(html_d5ee73495e1b4e61e7e084aeed086c5c);
#
#
#
#         marker_5132c7eb468210326d0725a478c86cb7.bindPopup(popup_130eb3b45
